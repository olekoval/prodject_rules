# %%
import pandas as pd
from pathlib import Path

BASE_DIR = Path(".").resolve()


data_path = BASE_DIR / "data" / "database.xlsx"

df_dicts = pd.read_excel(data_path, sheet_name="dicts")
df_rules = pd.read_excel(data_path, sheet_name="rules")
df_versions = pd.read_excel(data_path, sheet_name="rule_versions")

dff = (df_rules
       .merge(df_dicts, left_on='rule_service', right_on='cod')
       .merge(df_dicts, left_on='rule_clas', right_on='cod'))
dff = dff.rename(columns={'name_x': 'name_servise', 'name_y': 'name_clas'})

df_rule_names = (df_dicts[df_dicts['type'] == 'Правило'][['cod', 'name']]
                 .rename(columns={'cod': 'rule_code', 'name': 'rule_text'}))
dff = dff.merge(df_rule_names, on='rule_code', how='left')
dff = dff[['id', 'packet_number', 'rule_service', 'name_servise',
           'rule_clas', 'name_clas', 'rule_code', 'rule_text']]

services = df_dicts[df_dicts['type'] == 'Сервіс'][['cod', 'name']].to_dict('records')


def get_classes(service_cod):
    return (dff[dff['rule_service'] == service_cod][['rule_clas', 'name_clas']]
            .drop_duplicates()
            .rename(columns={'rule_clas': 'cod', 'name_clas': 'name'})
            .to_dict('records'))


def get_rules(service_cod, class_cod):
    return (dff[(dff['rule_service'] == service_cod) & (dff['rule_clas'] == class_cod)]
            [['id', 'rule_code', 'rule_text', 'packet_number']]
            .drop_duplicates()
            .to_dict('records'))


def get_version(rule_id):
    rows = df_versions[df_versions['rule_id'] == rule_id]
    if rows.empty:
        return None
    row = rows.sort_values('effective_from', ascending=False).iloc[0]
    return {
        'version_text': row['version_text'],
        'status': row['status'],
        'effective_from': str(row['effective_from'])[:10],
    }

# %%
dff
# Out:
#        id  packet_number rule_service             name_servise rule_clas  \
# 0    LR01              9           LR  Лабораторна діагностика        L0
# 1    LR02              9           LR  Лабораторна діагностика        L0
# 2    LR03              9           LR  Лабораторна діагностика        L0
# 3    LR11              9           LR  Лабораторна діагностика        L1
# 4    LR12              9           LR  Лабораторна діагностика        L1
# 5    LR13              9           LR  Лабораторна діагностика        L1
# 6    LR14              9           LR  Лабораторна діагностика        L1
# 7    LR15              9           LR  Лабораторна діагностика        L1
# 8    LR16              9           LR  Лабораторна діагностика        L1
# 9    LR17              9           LR  Лабораторна діагностика        L1
# 10   LR18              9           LR  Лабораторна діагностика        L1
# 11   LR21              9           LR  Лабораторна діагностика        L2
# 12   LR22              9           LR  Лабораторна діагностика        L2
# 13   LR23              9           LR  Лабораторна діагностика        L2
# 14   LR24              9           LR  Лабораторна діагностика        L2
# 15   LR25              9           LR  Лабораторна діагностика        L2
# 16   LR26              9           LR  Лабораторна діагностика        L2
# 17   LR27              9           LR  Лабораторна діагностика        L2
# 18   LR28              9           LR  Лабораторна діагностика        L2
# 19   LR29              9           LR  Лабораторна діагностика        L2
# 20  LR210              9           LR  Лабораторна діагностика        L2
# 21  LR211              9           LR  Лабораторна діагностика        L2
# 22  LR212              9           LR  Лабораторна діагностика        L2
#
#            name_clas rule_code  \
# 0   Загальні правила     LR.01
# 1   Загальні правила     LR.02
# 2   Загальні правила     LR.03
# 3        Гематологія    LR.1.1
# 4        Гематологія    LR.1.2
# 5        Гематологія    LR.1.3
# 6        Гематологія    LR.1.4
# 7        Гематологія    LR.1.5
# 8        Гематологія    LR.1.6
# 9        Гематологія    LR.1.7
# 10       Гематологія    LR.1.8
# 11          Біохімія    LR.2.1
# 12          Біохімія    LR.2.2
# 13          Біохімія    LR.2.3
# 14          Біохімія    LR.2.4
# 15          Біохімія    LR.2.5
# 16          Біохімія    LR.2.6
# 17          Біохімія    LR.2.7
# 18          Біохімія    LR.2.8
# 19          Біохімія    LR.2.9
# 20          Біохімія   LR.2.10
# 21          Біохімія   LR.2.11
# 22          Біохімія   LR.2.12
#
#                                             rule_text
# 0   Лабораторні дослідження, які підлягають оплаті...
# 1   Дослідження, які відсутні в Таблиці лабораторн...
# 2   Лабораторні дослідження обліковані електронним...
# 3                              Визначення гемоглобіну
# 4                 Проведення загального аналізу крові
# 5                     Визначення протромбінового часу
# 6       Кількісне визначення факторів згортання крові
# 7                             Визначення антитромбіну
# 8            Визначення основних ізоформ гемоглобіну,
# 9   Дослідження з кодами: N38001 D34001 B34003, W3...
# 10                               Дослідження класу L1
# 11              Кількісне визначення лужної фосфатази
# 12  Дослідження маркерів ураження серцевого або ск...
# 13                 Визначення субкласів ліпопротеідів
# 14                             Визначення вітаміну B1
# 15                            Визначення вітаміну B12
# 16   Визначення мозкового натрійуретичного пропептиду
# 17                            Визначення онкомаркерів
# 18           Визначення простатоспецифічного антигену
# 19                   Кількісне визначення фракцій ПСА
# 20           Визначення простатоспецифічного антигену
# 21  Кількісне визначення в крові або сечі гормонів...
# 22                                 Визначення глюкози

# %%
services
# Out:
# [{'cod': 'LR', 'name': 'Лабораторна діагностика'},
#  {'cod': 'IR', 'name': 'Інструментальна діагностика'}]

# %%
get_classes('LR')
# Out:
# [{'cod': 'L0', 'name': 'Загальні правила'},
#  {'cod': 'L1', 'name': 'Гематологія'},
#  {'cod': 'L2', 'name': 'Біохімія'}]

# %%
df_versions
# Out:
#     id rule_id  document_id    status effective_from  effective_to  \
# 0    1    LR01            1  Activate     2025-07-01           NaN
# 1    2    LR02            1  Activate     2025-01-01           NaN
# 2    3    LR03            1  Activate     2025-01-01           NaN
# 3    4    LR11            1  Activate     2025-01-01           NaN
# 4    5    LR12            1  Activate     2025-01-01           NaN
# 5    6    LR13            1  Activate     2025-01-01           NaN
# 6    7    LR14            1  Activate     2025-07-01           NaN
# 7    8    LR15            1  Activate     2025-07-01           NaN
# 8    9    LR16            1  Activate     2025-07-01           NaN
# 9   10    LR17            1  Activate     2025-07-01           NaN
# 10  11    LR18            1  Activate     2025-07-01           NaN
# 11  12    LR21            1  Activate     2025-01-01           NaN
#
#     change_description                                       version_text
# 0                  NaN  Лабораторні дослідження, які підлягають оплаті...
# 1                  NaN  Дослідження, які відсутні в Таблиці лабораторн...
# 2                  NaN  Лабораторні дослідження обліковані електронним...
# 3                  NaN  Визначення гемоглобіну (код B34018), гематокри...
# 4                  NaN  Проведення загального аналізу крові (код A3401...
# 5                  NaN  Визначення протромбінового часу (код 5902-2), ...
# 6                  NaN  Кількісне визначення факторів згортання крові:...
# 7                  NaN  Визначення антитромбіну III (код 27811-9), про...
# 8                  NaN  Визначення основних ізоформ гемоглобіну, зокре...
# 9                  NaN  За дослідження з кодами: N38001 D34001 B34003,...
# 10                 NaN  Дослідження класу L1 підлягають оплаті за умов...
# 11                 NaN  Кількісне визначення лужної фосфатази (код 676...
